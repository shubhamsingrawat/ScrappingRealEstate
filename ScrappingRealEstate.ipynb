# %%
import requests
from bs4 import BeautifulSoup
from fake_useragent import UserAgent
ua=UserAgent().chrome
headers={'User-agent':str(ua)}

# %%
# r = requests.get("http://www.pyclass.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/",
#                  headers={'User-agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:61.0) Gecko/20100101 Firefox/61.0'})

# %% [markdown]
# ### ua is creted to make server understant form where  the requees is coming from

# %%
# !pip install fake_useragent


# from fake_useragent import UserAgent
# ua=UserAgent().chrome
# headers={'User-agent':str(ua)}

# url="http://www.pyclass.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/"
# r=requests.get(url,headers=headers)

# %% [markdown]
# ## r is the request obvbject that contains various features like
# ### do help (r)

# %%
print(r)
# Out:
# <Response [200]>

# %%
# print(r.content)

# %%
# soup=BeautifulSoup(r.content,'html.parser')
# # print(soup)

# all_data=soup.find_all('div',{'class':'propertyRow'})
# # print(all_data)

# # data=soup.find_all('div',{'class':'propPrice'})
# # for price in data:
# #     print(price.text.replace("\n","").replace(" ",""))

# print(type(all_data))
# l=[]

# for data in all_data:
#     d={}
#     #print(data)
#     d['price']=data.find('h4',{'class':'propPrice'}).text.replace("\n","").replace(" ","")
#     d['address']=data.find_all('span',{'class':'propAddressCollapse'})[0].text
#     d['locality']=data.find_all('span',{'class':'propAddressCollapse'})[1].text
#     try:
#         d['bed']=data.find('span',{'class':'infoBed'}).text.split(" ")[0]
#     except:
#         d['bed']=None
#     try:
#         d['fullBath']=data.find('span',{'class':'infoValueFullBath'}).text
#     except:
#         d['fullBath']=None
#     try:
#         d['infoSqFt']=data.find('span',{'class':'infoSqFt'}).text
#     except:
#         d['infoSqFt']=None
    
#     for feat in data.find_all('div',{'class':'columnGroup'}):
#         for fgroup,fname in zip(feat.find_all('span',{'class':'featureGroup'}),feat.find_all('span',{'class':'featureName'})):
#             if "Lot Size:" in fgroup.text:
#                 d['lot size']=fname.text

#     l.append(d)

# %%
base_url="http://www.pyclass.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s="
l=[]
for i in range(0,30,10):
    print(base_url+str(i)+'.html')
    
    url="http://www.pyclass.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/"
    r=requests.get(url,headers=headers)
    
    soup=BeautifulSoup(r.content,'html.parser')
    all_data=soup.find_all('div',{'class':'propertyRow'})
    print(type(all_data))

    for data in all_data:
        d={}
        #print(data)
        d['price']=data.find('h4',{'class':'propPrice'}).text.replace("\n","").replace(" ","")
        d['address']=data.find_all('span',{'class':'propAddressCollapse'})[0].text
        d['locality']=data.find_all('span',{'class':'propAddressCollapse'})[1].text
        try:
            d['bed']=data.find('span',{'class':'infoBed'}).text.split(" ")[0]
        except:
            d['bed']=None
        try:
            d['fullBath']=data.find('span',{'class':'infoValueFullBath'}).text.split(" ")[0]
        except:
            d['fullBath']=None
        try:
            d['infoSqFt']=data.find('span',{'class':'infoSqFt'}).text
        except:
            d['infoSqFt']=None

        for feat in data.find_all('div',{'class':'columnGroup'}):
            for fgroup,fname in zip(feat.find_all('span',{'class':'featureGroup'}),feat.find_all('span',{'class':'featureName'})):
                if "Lot Size:" in fgroup.text:
                    d['lot size']=fname.text

        l.append(d)
# Out:
# http://www.pyclass.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s=0.html
# <class 'bs4.element.ResultSet'>
# http://www.pyclass.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s=10.html
# <class 'bs4.element.ResultSet'>
# http://www.pyclass.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s=20.html
# <class 'bs4.element.ResultSet'>

# %%
# print(l)
import pandas as pd
df=pd.DataFrame(l)
df
# Out:
#        price                address                locality   bed fullBath  \
# 0   $725,000              0 Gateway  Rock Springs, WY 82901  None     None
# 1   $452,900  1003 Winchester Blvd.  Rock Springs, WY 82901     4        4
# 2   $396,900          600 Talladega  Rock Springs, WY 82901     5        3
# 3   $389,900     3239 Spearhead Way  Rock Springs, WY 82901     4        3
# 4   $254,000     522 Emerald Street  Rock Springs, WY 82901     3        3
# 5   $252,900   1302 Veteran's Drive  Rock Springs, WY 82901     4        2
# 6   $210,000       1021 Cypress Cir  Rock Springs, WY 82901     4        3
# 7   $209,000         913 Madison Dr  Rock Springs, WY 82901     3        2
# 8   $199,900      1344 Teton Street  Rock Springs, WY 82901     3        2
# 9   $196,900         4 Minnies Lane  Rock Springs, WY 82901     3        2
# 10  $725,000              0 Gateway  Rock Springs, WY 82901  None     None
# ...

# %%
# n_data=data.find_all('div',{'id':'propertyRowREN021201395propertyFeatures'})
# n_data[1].text.split("\n")

# %%
df.to_csv('outrent.csv')

# %%
import os

# %%
print(os.getcwd())
# Out:
# C:\Users\lenovo\webScrapping
